# %% [markdown]
# ### Requests tests

# %%
import json
import sqlite3

# %%
import requests


headers = {
	'x-rapidapi-key': rapid_api_key,
	'x-rapidapi-host': rapidapi_host
}

# %%
def print_response(response):
    print(json.dumps(response.json(), indent=4))

# %% [markdown]
# #### Leagues

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/leagues"

querystring = {"country":"Spain"}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# Starting new HTTPS connection (1): api-football-v1.p.rapidapi.com:443
# https://api-football-v1.p.rapidapi.com:443 "GET /v3/leagues?country=Spain HTTP/1.1" 200 None

# %%
type(response.text)
# Out:
# str

# %%
print_response(response)
# Out:
# {
#     "get": "leagues",
#     "parameters": {
#         "country": "Spain"
#     },
#     "errors": [],
#     "results": 38,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "league": {
#                 "id": 140,
#                 "name": "La Liga",
#                 "type": "League",
#                 "logo": "https://media.api-sports.io/football/leagues/140.png"
#             },
#             "country": {
#                 "name": "Spain",
#                 "code": "ES",
#                 "flag": "https://media.api-sports.io/flags/es.svg"
#             },
#             "seasons": [
#                 {
#                     "year": 2010,
#                     "start": "2010-08-28",
#                     "end": "2011-05-21",
#                     "current": false,
#                     "coverage": {
#                         "fixtures": {
#                             "events": true,
# ...

# %%
for el in response.json()["response"]:
    if el["league"]["name"] == "La Liga":
        league = el

# %%
with open("data/league.json", "w") as f:
    json.dump(league, f)

# %%
response = requests.get(url, headers=headers, params={"country": "Spain", "name": "La Liga", "season":2022})
# Out:
# Starting new HTTPS connection (1): api-football-v1.p.rapidapi.com:443
# https://api-football-v1.p.rapidapi.com:443 "GET /v3/leagues?country=Spain&name=La+Liga&season=2022 HTTP/1.1" 200 None

# %%
print_response(response)
# Out:
# {
#     "get": "leagues",
#     "parameters": {
#         "country": "Spain",
#         "name": "La Liga",
#         "season": "2022"
#     },
#     "errors": [],
#     "results": 1,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "league": {
#                 "id": 140,
#                 "name": "La Liga",
#                 "type": "League",
#                 "logo": "https://media.api-sports.io/football/leagues/140.png"
#             },
#             "country": {
#                 "name": "Spain",
#                 "code": "ES",
#                 "flag": "https://media.api-sports.io/flags/es.svg"
#             },
#             "seasons": [
#                 {
#                     "year": 2022,
#                     "start": "2022-08-12",
#                     "end": "2023-06-04",
#                     "current": false,
#                     "coverage": {
#                         "fixtures": {
# ...

# %% [markdown]
# #### Teams

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/teams"

querystring = {"country":"Spain", "league":140, "season": 2022}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# Starting new HTTPS connection (1): api-football-v1.p.rapidapi.com:443
# https://api-football-v1.p.rapidapi.com:443 "GET /v3/teams?country=Spain&league=140&season=2022 HTTP/1.1" 200 None

# %%
print_response(response)
# Out:
# {
#     "get": "teams",
#     "parameters": {
#         "country": "Spain",
#         "league": "140",
#         "season": "2022"
#     },
#     "errors": [],
#     "results": 20,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "team": {
#                 "id": 529,
#                 "name": "Barcelona",
#                 "code": "BAR",
#                 "country": "Spain",
#                 "founded": 1899,
#                 "national": false,
#                 "logo": "https://media.api-sports.io/football/teams/529.png"
#             },
#             "venue": {
#                 "id": 19939,
#                 "name": "Estadi Ol\u00edmpic Llu\u00eds Companys",
#                 "address": "Carrer de l&apos;Estadi",
#                 "city": "Barcelona",
#                 "capacity": 55926,
#                 "surface": "grass",
#                 "image": "https://media.api-sports.io/football/venues/19939.png"
# ...

# %% [markdown]
# #### Teams stats

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/teams/statistics"

querystring = {"league":140, "season": 2022, "team":536}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# Starting new HTTPS connection (1): api-football-v1.p.rapidapi.com:443
# https://api-football-v1.p.rapidapi.com:443 "GET /v3/teams/statistics?league=140&season=2022&team=536 HTTP/1.1" 200 None

# %%
print_response(response)
# Out:
# {
#     "get": "teams/statistics",
#     "parameters": {
#         "league": "140",
#         "season": "2022",
#         "team": "536"
#     },
#     "errors": [],
#     "results": 11,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": {
#         "league": {
#             "id": 140,
#             "name": "La Liga",
#             "country": "Spain",
#             "logo": "https://media.api-sports.io/football/leagues/140.png",
#             "flag": "https://media.api-sports.io/flags/es.svg",
#             "season": 2022
#         },
#         "team": {
#             "id": 536,
#             "name": "Sevilla",
#             "logo": "https://media.api-sports.io/football/teams/536.png"
#         },
#         "form": "LDLLWDLDWDLLDLDWLWWLWDLLWLWDWWWLWWDDLL",
#         "fixtures": {
#             "played": {
#                 "home": 19,
#                 "away": 19,
#                 "total": 38
#             },
#             "wins": {
# ...

# %% [markdown]
# #### Standings (clasificación)

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/standings"

querystring = {"league":140, "season": 2022}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# Starting new HTTPS connection (1): api-football-v1.p.rapidapi.com:443
# https://api-football-v1.p.rapidapi.com:443 "GET /v3/standings?league=140&season=2022 HTTP/1.1" 200 None

# %%
print_response(response)
# Out:
# {
#     "get": "standings",
#     "parameters": {
#         "league": "140",
#         "season": "2022"
#     },
#     "errors": [],
#     "results": 1,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "league": {
#                 "id": 140,
#                 "name": "La Liga",
#                 "country": "Spain",
#                 "logo": "https://media.api-sports.io/football/leagues/140.png",
#                 "flag": "https://media.api-sports.io/flags/es.svg",
#                 "season": 2022,
#                 "standings": [
#                     [
#                         {
#                             "rank": 1,
#                             "team": {
#                                 "id": 529,
#                                 "name": "Barcelona",
#                                 "logo": "https://media.api-sports.io/football/teams/529.png"
#                             },
# ...

# %% [markdown]
# #### Fixture (eventos, partidos)

# %% [markdown]
# ##### Jornadas

# %%
import requests

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/fixtures/rounds"

querystring = {"league":140, "season": 2022}

response = requests.get(url, headers=headers, params=querystring)

# %%
print_response(response)
# Out:
# {
#     "get": "fixtures/rounds",
#     "parameters": {
#         "league": "140",
#         "season": "2022"
#     },
#     "errors": [],
#     "results": 38,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         "Regular Season - 1",
#         "Regular Season - 2",
#         "Regular Season - 3",
#         "Regular Season - 4",
#         "Regular Season - 5",
#         "Regular Season - 6",
#         "Regular Season - 7",
#         "Regular Season - 8",
#         "Regular Season - 9",
#         "Regular Season - 10",
#         "Regular Season - 11",
#         "Regular Season - 12",
#         "Regular Season - 13",
#         "Regular Season - 14",
#         "Regular Season - 15",
#         "Regular Season - 16",
#         "Regular Season - 17",
#         "Regular Season - 18",
#         "Regular Season - 19",
#         "Regular Season - 20",
#         "Regular Season - 21",
#         "Regular Season - 22",
# ...

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"

querystring = {"league":140, "season": 2022, "round" : "Regular Season - 1"}

response = requests.get(url, headers=headers, params=querystring)

# %%
print_response(response)
# Out:
# {
#     "get": "fixtures",
#     "parameters": {
#         "league": "140",
#         "round": "Regular Season - 1",
#         "season": "2022"
#     },
#     "errors": [],
#     "results": 10,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "fixture": {
#                 "id": 877942,
#                 "referee": "Javier Iglesias",
#                 "timezone": "UTC",
#                 "date": "2022-08-15T15:30:00+00:00",
#                 "timestamp": 1660577400,
#                 "periods": {
#                     "first": 1660577400,
#                     "second": 1660581000
#                 },
#                 "venue": {
#                     "id": 1460,
#                     "name": "San Mam\u00e9s Barria",
#                     "city": "Bilbao"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
# ...

# %%
# Se podría dejar para una versión posterior

# %% [markdown]
# ##### Head to head (histórico de enfrentamientos entre 2 equipos)

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/fixtures/headtohead"

querystring = {"league":140, "season": 2022, "h2h":"536-543"}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# Starting new HTTPS connection (1): api-football-v1.p.rapidapi.com:443
# https://api-football-v1.p.rapidapi.com:443 "GET /v3/fixtures/headtohead?league=140&season=2022&h2h=536-543 HTTP/1.1" 200 None

# %%
print_response(response)
# Out:
# {
#     "get": "fixtures/headtohead",
#     "parameters": {
#         "league": "140",
#         "h2h": "536-543",
#         "season": "2022"
#     },
#     "errors": [],
#     "results": 2,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": [
#         {
#             "fixture": {
#                 "id": 878288,
#                 "referee": "Jes\u00fas Gil",
#                 "timezone": "UTC",
#                 "date": "2023-05-21T19:00:00+00:00",
#                 "timestamp": 1684695600,
#                 "periods": {
#                     "first": 1684695600,
#                     "second": 1684699200
#                 },
#                 "venue": {
#                     "id": 1494,
#                     "name": "Estadio Ram\u00f3n S\u00e1nchez Pizju\u00e1n",
#                     "city": "Sevilla"
#                 },
#                 "status": {
#                     "long": "Match Finished",
#                     "short": "FT",
# ...

# %% [markdown]
# ##### fixtures/statistics

# %% [markdown]
# Estadísticas de un equipo durante un partido

# %% [markdown]
# ##### fixtures/events

# %% [markdown]
# Tarjetas, VAR, goles, intrapartido

# %% [markdown]
# ##### Otros: alineaciones y estadísticas de jugador intrapartido

# %% [markdown]
# #### Predictions

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/standings"

querystring = {"league":140, "season": 2022}

response = requests.get(url, headers=headers, params=querystring)
# Out:
# Starting new HTTPS connection (1): v3.football.api-sports.io:443
# https://v3.football.api-sports.io:443 "GET /standings?league=140&season=2022 HTTP/1.1" 200 None

# %%
print_response(response)
# Out:
# {
#     "get": "standings",
#     "parameters": {
#         "league": "140",
#         "season": "2022"
#     },
#     "errors": {
#         "token": "Error/Missing application key. Go to https://www.api-football.com/documentation-v3 to learn how to get your API application key."
#     },
#     "results": 0,
#     "paging": {
#         "current": 1,
#         "total": 1
#     },
#     "response": []
# }
# '{\n    "get": "standings",\n    "parameters": {\n        "league": "140",\n        "season": "2022"\n    },\n    "errors": {\n        "token": "Error/Missing application key. Go to https://www.api-football.com/documentation-v3 to learn how to get your API application key."\n    },\n    "results": 0,\n    "paging": {\n        "current": 1,\n        "total": 1\n    },\n    "response": []\n}'

# %% [markdown]
# _____

# %%
import json
import sqlite3
import requests
import time
import pandas as pd
headers = {
	'x-rapidapi-key': rapid_api_key,
	'x-rapidapi-host': rapidapi_host
}
